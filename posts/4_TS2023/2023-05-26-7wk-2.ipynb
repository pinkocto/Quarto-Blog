# %% [raw]
# ---
# title: " **[TS]** 7wk-2. 6장 연습문제 (++)"
# author: "jiyunLim"
# date: "05/24/2023"
# categories:
#     - STUDY
#     - TS
# ---

# %% [markdown]
# ## 일반적인 ARMA(p,q)

# %% [markdown]
# 1. 처음 $(q+1)$개의 eq를 연립하여 $\gamma_0,\dots, \gamma_q$를 구한다.
# 2. 이후의 eq은 항상 아래의 형태를 따름.

# %% [markdown]
# $\gamma_{q+1} = \phi_1\gamma_q + \phi_2\gamma_{q-1} + \dots +\phi_p\gamma_{q-p+1}$

# %% [markdown]
# $\gamma_{q+2} = \phi_1\gamma_{q+1} + \phi_2\gamma_{q} + \dots + \phi_p\gamma_{q-p+2}$

# %% [markdown]
# $\vdots$

# %% [markdown]
# $AR(p)$모형과 동일. 즉, $\gamma_{q-p+1}$ 이후의 ACF 모양이 $AR(p)$ 모형의 ACF 모양과 동일.

# %% [markdown]
# $\therefore ARMA(p,q)$ 모델의 ACF.

# %% [markdown]
# ![](attachment:00297474-712e-4d47-a7c6-40fb01a302da.png)

# %% [markdown]
# tail off after lag $q-p.$

# %% [markdown]
# tails off

# %% [markdown]
# ## 6.3

# %% [markdown]
# 정상성 조건을 만족하면, AR모형을 MA모형으로 나타내라.

# %% [markdown]
# `-` 모델1: $Z_t = 158 + 0.8Z_{t-1} + \epsilon_t$

# %% [markdown]
# (a) 정상성 만족

# %% [markdown]
# (B) MA모형으로
#
# $(1-0.8B)(Z_t-\mu)=\epsilon_t.$
#
# $0.2\mu = 158.\to \mu=158\times 5$
#
# $Z_t = \mu + \epsilon_t + 0.8\epsilon_{t-1}+\dots\\
# \quad =\mu + \frac{1}{1-0.8B}\epsilon_t$

# %% [markdown]
# `-` 모델2: $(1-1.3B+0.5B^2)(Z_t-3.5)=\epsilon_t$

# %% [markdown]
# ![](attachment:3bd6954e-5eb6-4710-ae85-7fcefd78338f.png)

# %% [markdown]
# ![다른풀이](attachment:19d31bc1-4eb6-4b59-9ed9-ced936665af3.png)

# %% [markdown]
# (B)

# %% [markdown]
# ![](attachment:03aa2c1f-d462-4a54-a4f5-853038427441.png)

# %% [markdown]
# `-` 모형3: $0.5Z_{t-1}+0.6Z_{t-2}+\epsilon_t$

# %% [markdown]
# ![](attachment:57cc38a0-a937-490d-8120-49de16217b9b.png)

# %% [markdown]
# ## 6.4

# %% [markdown]
# ![](attachment:0b00b892-550a-497b-9b68-bbde0bf6f9c4.png)

# %% [markdown]
# ![](attachment:58b490b9-0f27-46db-b92d-8ae0798d6619.png)

# %% [markdown]
# ![](attachment:9c13872f-d8db-44b3-85d4-987781a19a20.png)

# %% [markdown]
# ## 6.5

# %% [markdown]
# ## 6.6
