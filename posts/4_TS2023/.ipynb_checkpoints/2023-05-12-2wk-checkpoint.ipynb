# %% [raw]
# ---
# title: " **[TS]** 2wk. 확률과정과 정상성"
# author: "JiyunLim"
# date: "05/12/2023"
# categories:
#     - STUDY
#     - TS
# ---

# %% [markdown]
# ## 확률변수: (조금 특별한 성질을 가진) 함수
#
# - 정의역: $\Omega$
# - 치역: $\mathbb{R}$의 부분집합

# %% [markdown]
# ### 동전예제

# %% [markdown]
# $\Omega = \{H,T\}$

# %% [markdown]
# $X: \Omega \to \mathbb{R}$

# %% [markdown]
# ![](attachment:19ddc5e6-2cc2-4f8b-9350-8e5071bf53a0.png)

# %% [markdown]
# `-` 기호

# %% [markdown]
# 집합: $\Omega$, 원소: $w$, $\quad w\in \Omega$

# %% [markdown]
# $\Omega = \{H,T\} = \{w_1,w_2\}$

# %% [markdown]
# $X(w_1) = X(H)=0, X(w_2) = X(T)=1$

# %% [markdown]
# `-` 주의

# %% [markdown]
# - $X: \Omega \to \mathbb{R}$
# - $P: \cal{F} \to [0,1]$ (set function)

# %% [markdown]
# ***(참고)*** $\cal{F}$: $\Omega$의 부분집합 중 잴 수 있는 집합의 모임.

# %% [markdown]
# ![](attachment:61241801-a745-4628-8c69-ca0f8e0d5298.png)

# %% [markdown]
# ### 확률변수에 대한 오해: 확률변수 = 값이 랜덤하게 바뀌는 변수

# %% [markdown]
# **<font color='red'>"확률변수는 (특별한 성질을 가진) 함수다!"</font>**

# %% [markdown]
# 함수: $\begin{align*}&y=f(x), \quad f: \text{function}, x: \text{input}, y:\text{outcome}\\
# & x=X(w) \quad X: \text{random variable}, w: \text{outcome}, x: \text{realization}\end{align*}$

# %% [markdown]
# 보통 $X(w)$에서 $(w)$를 생략하고, 간단히 $X$로 표시 $\to$ 혼란의 이유!

# %% [markdown]
# **<font color='red'>"확률변수는 결과가 랜덤으로 변한다."</font>**

# %% [markdown]
# `1` 맵핑규칙은 변화없음.
#
# - $H\to 0 \quad w_1 \to 0$
# - $T\to 1 \quad w_2 \to 1$

# %% [markdown]
# `2` 입력. 즉, outcome은 실험결과에 따라 랜덤으로 변한다.

# %% [markdown]
# ### 예제1

# %% [markdown]
# > w.p는 with probability를 의미.

# %% [markdown]
# 확률변수 $X = \begin{cases} 0, & \text{w.p. } \frac{1}{2} \\
# 1 & \text{w.p. } \frac{1}{2}\end{cases}$

# %% [markdown]
# `(i)` $X$는 변수처럼 보임.

# %% [markdown]
# `(ii)` 변수의 값이 랜덤으로 변하는 것 같음

# %% [markdown]
# $X(w) = \begin{cases} 0, & w\in \{H\}  \\
# 1, &  w\in \{T\} \end{cases}$

# %% [markdown]
# ### 요약

# %% [markdown]
# 1. 확률변수는 확률과 관련 없다.
# 2. 간접적으로는 관련있다. ($\therefore$ $X$의 역상 $= \Omega$의 부분집합 $=P$의 정의역)

# %% [markdown]
# ### 질문: 확률변수 X의 모든 역상에 대하여 확률을 모순없이! 정의가능?

# %% [markdown]
# `-` 시계예제

# %% [markdown]
# $\Omega=[0,2\pi) \qquad X: [0,2\pi)\to [0,2\pi)$인 항등함수.

# %% [markdown]
# $X$는 항등함수 $\Rightarrow$ 비탈리 집합의 역상은 비탈리집합 $\Rightarrow$ 확률을 정의할 수 X

# %% [markdown]
# ### 합의

# %% [markdown]
# <font color='blue'>**"확률변수 $X$를 그냥 함수가 아니라, 역상이 measurable set이 되는 함수라 하자."**</font> $\Leftrightarrow$ $X$를 **가측함수**^[measurable function]라고 하자.

# %% [markdown]
# ## 시계열 intro1

# %% [markdown]
# - 확률변수 $X$: $\Omega\to \mathbb{R}$인 특별한 함수.
# - 확률벡터 $\bf{X}: \Omega\to \mathbb{R}^m$인 특별한 함수

# %% [markdown]
# `-` 기호

# %% [markdown]
# 확률변수: $X(w) = x$
#
# 확률벡터: $\bf{X}(w) = (x_1,\dots, x_m)$ $\to$ 출력이 벡터임을 강조!

# %% [markdown]
# 확률변수: $X$
#
# 확률벡터: $\mathbf{X} = (X_1,\dots,X_m), \quad X_1,\dots,X_m$은 $r.v.$
#
# $\therefore \bf{X} = (X_1,\dots, X_m)(w) = (X_1(w),\dots,X_m(w))=(x_1,\dots,x_m)$

# %% [markdown]
# $x_1 = \text{2019-03-20} \\
# x_2 = \text{2019-03-21} \\
# \qquad \vdots$

# %% [markdown]
# $\therefore x_1,\dots, x_m \Rightarrow \text{2019-03-20}$ 부터 순서대로 $m$개의 삼전주식값을 나열

# %% [markdown]
# ***Note!*** : $w$만 알면 $x_1,\dots,x_m$의 값이 저절로 결정.

# %% [markdown]
# $X_1(w) = x_1 \\
# X_2(w) = x_2,\\
# \qquad \vdots$

# %% [markdown]
# `-` **가능한 설명모형**

# %% [markdown]
# (1) $14,000,605$ 개의 평행세계

# %% [markdown]
# (2) 우리는 이 중 하나의 세계에 $\frac{1}{14,000,605}$의 "확률"로 선택되어져 살고있음.

# %% [markdown]
# $\Rightarrow \Omega=\{w_1,w_2,\dots, w_{14,000,605}\}$

# %% [markdown]
# $P(\{w_1\})=P(\{w_2\})=\dots=P(\{w_{14,000,605}\})=\frac{1}{14,000,605}$

# %% [markdown]
# (3) 하나의 평행세계가 선택 $\Rightarrow$ 그 평행세계의 모든 사건이 이미 결정.

# %% [markdown]
# 우리의 우주 $=$ $777$번째 평행세계 $\Rightarrow w=w_{777}$

# %% [markdown]
# ![](attachment:0c482988-2136-4e9b-829e-a17846af63c1.png)

# %% [markdown]
# `-` **반론** : 미래는 고정되지 않음.

# %% [markdown]
# $m+1$ 시점은 총 $52,210-38,590=13,620$개의 미래가 가능!

# %% [markdown]
# `-` **반론의 반론** : 처음부터 $14,000,605 \times 13,620$ 의 미래를 고려.

# %% [markdown]
# - $m$개의 삼전 주가 $\Rightarrow 14,000,605$
#
# - $m+1$개의 삼전주가 $\Rightarrow 14,000,605 \times 13,620$

# %% [markdown]
# `-` **동전 2회**

# %% [markdown]
# $\Omega = \{\{H,H\}, \{H,T\}\,\{T,H\}, \{T,T\}\}$

# %% [markdown]
# $\{H,H\}: w_1 \\ \{H,T\}:w_2 \\ \{T,H\}: w_3 \\ \{T,T\}:w_4$

# %% [markdown]
# ### 복습: 확률변수

# %% [markdown]
# ![](attachment:30ede8b8-2f25-423b-8243-0e8479e0959b.png)

# %% [markdown]
# ### 기호정리

# %% [markdown]
# - 확률변수: $X(w) = x$.
# - 확률벡터: $\bf{X}(w) = \left(X_1(w),\dots,X_m(w)\right)=(x_1,\dots,x_m)$
# - 확률과정: $X(w,t) = x_t = x(t)$
#     - 확률과정은 $w$와 $t$의 함수.
#     - $X(w,t)$를 $X_t(w)$로 표기하기도 함.
#     - 고정된 $w \Rightarrow$ relization이 시간에 따른 함수
#     - 고정된 $t \Rightarrow$ random variable이 함수

# %% [markdown]
# `(참고)` : 고정된 $w$에 대한 $X(w,t)$의 relization을 sample path 혹은 sample function이라고 부른다.

# %% [markdown]
# ### 용어정리1 ($\star\star\star$)

# %% [markdown]
# $\Omega = \{w_1,\dots, w_{14,000,605}\}$ 이런 평행세계가 있다...

# %% [markdown]
# ![](attachment:3dc40414-f922-4173-9446-73895da2b88e.png)

# %% [markdown]
# 각각의 $\omega$에 매핑되는 함수(무한 개의 값들)가 있을 것이고, 시점을 $t_0$로 고정하면, 첫번째 평행세계에 대해서는 $X(w_1, t_0)$, 두번째 평행세계에 대해서는 $X(w_2, t_0)$, 세번째 평행세계에 대해서는 $X(w_3, t_0)$가 된다.

# %% [markdown]
# ### 용어정리2

# %% [markdown]
# 모든 $\omega$에 대하여 가능한 sample path를 모두 모은 뭉치. $\Rightarrow$ **앙상블(ensemble)**

# %% [markdown]
# ![앙상블(ensemble)](attachment:90cf2fe9-2d83-4aa9-815f-0c630ee86a22.png)

# %% [markdown]
# ![](attachment:0eb9f55e-0832-46ea-960f-23664cb7ea2e.png)

# %% [markdown]
# 앙상블 mean: 1번 timeseries, $\dots$ 14,000,605번 timeseries를 다 더해서 평균을 낸 것

# %% [markdown]
# - 앙상블 mean : $\sum_{i=1}^{14,000,605}\frac{1}{14,000,605}\times(w_i,t) \Rightarrow \sim$어떤 함수값 (mean function이라고 표현을 많이 함.)

# %% [markdown]
# ![Time Average: 하나의 평행세계의 모든 시점에 대해 평균낸 것.](attachment:bdba275c-7f28-4c50-9cc5-528ef5b14bff.png)

# %% [markdown]
# 결국 확률변수 $X(w)$를 줄여서 $X$로 쓰고, 확률벡터 $\bf{X}(w)$를 줄여서 $\bf{X}$라 쓰고, 확률과정 $X(w,t)$를 줄여서 $X(t)$라고 쓴다.
#
# - $X(w) \to X$
# - $\bf{X}(w) \to \bf{X}$
# - $X(w,t) \to X(t)$ 또는 $X_t$

# %% [markdown]
# 연속 시계열은 확률과정 그 자체이고, 이산 시계열은 원소의 수가 무한한 확률벡터라고 생각할 수 있다.우리가 많이 다루는 것은 이산 시계열이다.

# %% [markdown]
# ## 시계열 intro2

# %% [markdown]
# 시계열: 무한차원의 확률벡터 or. **확률과정의 smaple** 버전이라고 생각할 수 있다. $(x_1, x_2, \dots, \dots)$

# %% [markdown]
# $\{Z_t(w), \quad t=1,2,\dots\}, \quad$ $\omega$: 평행세계의 인덱스

# %% [markdown]
# ### 교재의 표현정리

# %% [markdown]
# 1. 확률과정: $X(t)$
# 2. 확률법칙: $P$
# 3. 확률공간: $(\Omega,\cal{F}, P)$
# 4. 확률변수: $X$
# 5. 확률변수의 모임: $\bf{X}, X(t)$ $\leftarrow$ 확률벡터나 확률과정 모두 의미.
# 6. 집합 T: index set of random element^[random variable, random vector, stochastic process 모두를 포함한다.]
#     - T의 원소가 1개이면 **확률변수**
#     - T의 원소가 유한개이면 **확률벡터**
#     - T의 원소가 무한개이면 **확률과정**
# 7. 연속형 확률과정 $= \{X(t), \quad t\in (0,\infty)\}$
#     - 집합 T가 $(0,\infty)$와 같이 구간으로 표현된 경우.
# 8. 이산형 확률과정: ($X_1,X_2,X_3,\dots), (\dots, X_{-1},X_0,X_1,X_2,\dots)$
#     - 집합T가 $\{1,2,3,\dots\}, \{\dots,-1,0,1,2,\dots\}$
# 9. 실현값 (realization)
#     - $x$ : 확률변수의 relization
#     - $(x_1,\dots, x_m)$ : 확률벡터의 relization
#     - $x(t)$ : 확률과정의 relization
# 10. 표본통로 (sample path): $x(t)$

# %% [markdown]
# ### 확률과정 노테이션 정리

# %% [markdown]
# ![](attachment:dc728d93-8718-42d5-8bc3-cb6d9037c72d.png)

# %% [markdown]
# ### 정상성

# %% [markdown]
# > 정상성 가정이 안되면 시계열분석의 의미가 없다.

# %% [markdown]
# ![ensemble](attachment:fcca09e3-35e2-4e3c-addc-db5f532d9998.png)

# %% [markdown]
# ![](attachment:3797d044-3595-4bb1-ab73-3ab0b86eb75b.png)

# %% [markdown]
# ### 예제1. 동전 3번던지기

# %% [markdown]
# 동전을 3번 던지면 나올 수 있는 모든 경우의 수는 8가지. 따라서 평행세계가 8개 있다고 하자.

# %% [markdown]
# $\Omega = \{w_1,\dots,w_8\} = \{HHH,\dots, TTT\}$

# %% [markdown]
# $P(w_1) = P(w_2) = \dots = P(w_8)=\frac{1}{8}$

# %% [markdown]
# - $\bf{X}(HHH) = (X_1(HHH),X_2(HHH),X_3(HHH)) = (0,0,0) \leftarrow$확률벡터
#
# - $\bf{X}(TTT) = (X_1(TTT),X_2(TTT),X_3(TTT)) = (1,1,1) \leftarrow$확률벡터

# %% [markdown]
# `-` 동전을 무한번 던진다? $\to$ 무한 개의 평행세계

# %% [markdown]
# $X_t = (X_1,X_2,X_3,X_4,\dots) \leftarrow$ 이산형확률과정 (베르누이 과정)

# %% [markdown]
# $x_t = (x_1,x_2,x_3,x_4,\dots) \leftarrow$ relization

# %% [markdown]
# 동전을 평생던져야 함.

# %% [markdown]
# **현실적인 관측** : $(x_1,\dots, x_{t^*-1})\leftarrow t^*-1$

# %% [markdown]
# **질문** : $E(X+t^*)=\frac{1}{2}\times 0 +  \frac{1}{2}\times 1 = \frac{1}{2}$

# %% [markdown]
# **디펜스** : 니가 동전이 공평한 동전인지 어떻게 아느냐?

# %% [markdown]
# ![큰수의 법칙: 동전을 계속던지다보면 1/2로 수렴하지 않느냐?](attachment:b2f2182b-228d-4869-bbab-0d4644bf32a9.png)

# %% [markdown]
# 계속 던지다 보니까 1/2이 나오잖아?

# %% [markdown]
# 하지만 시계열 문제에서는 이런식으로 대답을 못한다. 왜냐? $n$이 하나밖에 없잖아..(반복실험 자체가 불가능하다.^[우리가 살고있는 세계가 여러번 관측될 수는 없잖아])

# %% [markdown]
# **시계열 문제** : $n=1$

# %% [markdown]
# 대안: $\sum_{t=1}^{t^*-1}x_t/(t^*-1)$로 ensemble average를 추론.
#
# > $\sum_{t=1}^{t^*-1}x_t/(t^*-1)$를 time average라고 함.

# %% [markdown]
# ![](attachment:47aba206-b6e6-4835-996e-525d8440d7e4.png)

# %% [markdown]
# **iid 일경우** : time average로 ensemble average를 추론. (주황선)
#
# $\Rightarrow$ iid의 가정을 약화시키기 위한 노력이 필요함.
#
# $\Rightarrow$ 이러한 노력의 결과물이 **stationary 가정**임.
#
# stationary 가정은 관측치끼리 독립일 필요도 없고 uncorrelated 되어야할 필요도 없다.

# %% [markdown]
# $\Rightarrow$ 정상성가정이 없다면 $\Rightarrow$ 시계열 분석을 할 이유가 없다.

# %% [markdown]
# - 에르고딕..

# %% [markdown]
# **iid일 경우 단점** : 쓸모가 없다. iid를 가정할 수 있으면, 회귀분석을 돌리면 되는데 시계열을 돌릴 필요가 없다. iid가 안되기 때문에 시계열을 돌리는 것.
# > 과거의 사건이 현재의 사건과 correlation이 있다고 믿고, 독립이 아니라고 믿기 때문에 분석이 어려운 것..

# %% [markdown]
# 결국 iid 보다 약한 가정을 찾다보니 stationary라는 가정이 생기게 됨.

# %% [markdown]
# ## Stationary 종류

# %% [markdown]
# Stationary 과정은 크게 2가지 버전이 있습니다. Strictly Stationary 버전과 Weak Stationary 버전.

# %% [markdown]
# Strictly Stationary가 더 엄밀한 의미에서의 정상성인데 다루기 힘들다. 어떤 시계열이 strictly stationary하다는 것을 밝히기 쉽지 않다. 그래서 약화된 버전인 Weak Stationary를 많이 사용한다.

# %% [markdown]
# 에러텀이 normal 일 경우에는  strictly stationary와 weak stationary의 정의가 같아진다.

# %% [markdown]
# ### Strictly Stationary

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Definition:</b><br>
# 시계열 $\{X_t\}$ is strictly stationary.^[교재에서는 강한 의미의 정상성이라고 표현합니다.]
#
# $\Leftrightarrow \forall t_1,\dots,t_n \in T$ & $h\in \mathbb{Z}$: $\quad (X_{t_1},\dots,X_{t_n}) \overset{d}{=}(X_{t_1+h}, \dots, X_{t_n+h})$
#
# 시계열 $X_t$의 모든 finite한 샘플에 대해 어떤 임의의 lag에 대해서 확률벡터가 뽑히게 될텐데  확률벡터의 결합분포는 확률벡터를 $h$만큼 민 또 다른 확률벡터의 결합분포와 동일하다는 의미입니다.
# </div>

# %% [markdown]
# **`예제`**

# %% [markdown]
# $\{X_t\},\quad t\in \cal{T}=\{0,1,2,3,\dots\}$ $\Rightarrow X_0, X_1, X_2,X_3,X_4,X_5,X_6,X_7,X_8,X_9,X_{10}$

# %% [markdown]
# 다음의 6개의 샘플을 뽑았다고 하자. $h=3$이라고 하자.

# %% [markdown]
# $(X_1,X_3,X_5,X_7,X_9,X_{10}) \overset{d}{=}(X_{1+3},X_{3+3},X_{5+3},X_{7+3},X_{9+3},X_{10+3})$

# %% [markdown]
# 이는 시간 축을 $h$ 만큼 이동하여도 결합확률밀도함수가 동일하다는 것을 의미하며, **"strictly stationary"** 라고 합니다.

# %% [markdown]
# - lag이 3이든, 4이든 결합분포가 다 똑같아야 합니다. $\to$ 되게 강한 조건
#
# - finite sample을 예제 처럼 안뽑고 다르게 뽑더라도 어떤 lag에 관해서도 결합분포가 다 똑같아야 합니다.

# %% [markdown]
# ### Weak Stationary

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Definition:</b><br>
# 시계열 $\{X_t\}$ is weak stationary.^[교재에서는 약한 의미의 정상성, 2차 정상성, 혹은 공분산정상성을 갖는다고 표현합니다.]
#
# $\Leftrightarrow E(X_t), \text{Cov}(X_t, X_{t+h})$ is not depend on $t$.
# </div>

# %% [markdown]
# 평균과 공분산이  $t$에 의존하지 않는다는 의미이고 그래서 당연히 strictly stationary 하면 weak stationary 하게 됩니다.

# %% [markdown]
# $\bf{X}=\bf{X}_t = (o,o,\dots, o,o,\dots) \to$ 무한차원 확률벡터

# %% [markdown]
# $E\bf{X}_t = (o,o,\dots, o,o,\dots) \to$ 무한차원의 벡터

# %% [markdown]
# $\text{Cov}(\bf{X}) = \begin{bmatrix} Cov(X_0,X_0)&Cov(X_0,X_1)&Cov(X_0,X_2)&Cov(X_0,X_3)&\dots \\
# Cov(X_1,X_1)&Cov(X_1,X_1)&Cov(X_1,X_2)&Cov(X_1,X_3)&\dots\\
# Cov(X_2,X_1)&Cov(X_2,X_1)&Cov(X_2,X_2)&Cov(X_2,X_3)&\dots\\
# \vdots&\vdots&\vdots&\vdots&\dots
# \end{bmatrix}\to$ 무한차원의 매트릭스

# %% [markdown]
# $t$에 디펜드 하지 않다는 것은 $t$에 따라 값이 일정하다는 의미. 즉, 분산이 일정하다는 의미!^[$Cov(X_0,X_0)=Cov(X_1,X_1)=Cov(X_2,X_2)=\dots$]

# %% [markdown]
# ![색이 같은 부분은 값이 동일함을 나타냅니다.](attachment:3206f6f7-8d3e-4630-add2-495782962e39.png)

# %% [markdown]
# 정의상 lag을 임의로 밀어도 평균이나 공분산은 바뀌지 않음을 말하고 있다. 강스테이셔너리에서는 lag을 임의로 밀어도 분포가 같은것을 의미하고 여기서는 lag을 임의로 밀어도 평균이나 공분산이 같음을 말함.

# %% [markdown]
# $$Cov(X_0,X_1) \overset{lag1}{=}Cov(X_1,X_2)$$

# %% [markdown]
# $$Cov(X_0,X_1) \overset{lag2}{=}Cov(X_2,X_3)$$
