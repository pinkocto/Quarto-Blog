# %% [raw]
# ---
# title: " **[TS]** 3wk. 여러가지 확률과정 (random walk, AR)"
# author: "JiyunLim"
# date: "05/14/2023"
# categories:
#     - STUDY
#     - TS
# ---

# %% [markdown]
# # 5.2.1 White noise

# %% [markdown]
# $\{\epsilon_t\}$ is white noise iff^[if and only if의 약자, $\Leftrightarrow$]. $\epsilon_t \overset{\text{i.i.d.}}{\sim}(\mu,\sigma^2)$ for all $t$.

# %% [markdown]
# 회귀분석에서는 보통 normal 가정을 하는데^[confidence interval을 구하기 위해서.] 여기서는 normal 가정이 필요 없다. (uniform이나 다른 가정 가능)

# %% [markdown]
# `-` 특징

# %% [markdown]
# for all $t$ $\quad E(\epsilon_t)=\mu, V(\epsilon_t)=\sigma^2$

# %% [markdown]
# for all $l\geq 0$ $\quad \text{Cov}(\epsilon_{t-l},\epsilon_t)=0$ *여기서 $l$은 lag의 약자.*

# %% [markdown]
# $\Rightarrow$ Stationary Process^[너무나 당연해, iid조건을 약화시켜 만든것이 stationary니까!]

# %% [markdown]
# 히스토리를 보면 왜 당연한건지 알 수 있다. i.i.d.인 경우에는 에르고딕 성질이 있다..iid는 너무 강한 조건이니까 약한 조건을 찾다 약화시키고 약화시키다보니 Stationary Process가 되었다. 그러니까 당연히 iid는 stationary가 된다.

# %% [markdown]
# # 5.2.2 random walk process

# %% [markdown]
# $\{Z_t\}$ is random walk process $\Leftrightarrow$ $Z_t = Z_{t-1} + \epsilon_t, \quad \epsilon_t\sim (0,\sigma^2)$

# %% [markdown]
# 쉽게말해, 현재 상태를 이전상태와 오차와의 합으로 표현할 수 있는 프로세스. 상당히 유용한 모델입니다.

# %% [markdown]
# `-` 특징: 합리적이고, 실용적인듯함.
#
# - 현재 = 과거 + 오차 (=랜덤한 변동)
# - $Z_t = Z_{t-1} +$ 변동

# %% [markdown]
# `-` 단점: 쓸모가 없다. <- non-stationary 모델이기 때문에

# %% [markdown]
# `(1)` 처음을 $t$시점으로 두고 $-\infty$로 보내는 방법

# %% [markdown]
# $Z_t = Z_{t-1} + \epsilon_t \quad \epsilon_t\sim (0,\sigma^2)$

# %% [markdown]
# $\space\quad=Z_{t-2} + \epsilon_{t-1} + \epsilon_{t}$

# %% [markdown]
# $\space\quad=Z_{t-3} + \epsilon_{t-2} + \epsilon_{t-1} +\epsilon_{t}$

# %% [markdown]
# $\space\quad\quad\quad \vdots$

# %% [markdown]
# $\space\quad=\epsilon_{t} + \epsilon_{t-1} + \epsilon_{t-2} + \epsilon_{t-3} + \dots + Z_{-\infty}$

# %% [markdown]
# $V(Z_t) = \sigma^2 + \sigma^2 + \sigma^2 + \dots = \infty$

# %% [markdown]
# *편의상 $Z_{-\infty}$를 $0$이라고 놨지만, 엄밀하게 따지면 $Z_{-\infty}$ 값이 존재합니다.*

# %% [markdown]
# 분산이 무한대니까 stationary가 아닙니다. $t$에 depend하는 것을 따지기 전에 우선 분산이 finite해야 해요. finite한 상태에서 $t$에 depend하면 stationary가 안되겠죠?

# %% [markdown]
# 그래서 이 모델은 분산이 무한대이니까 stationary가 안되고 그래서 쓸모가 없는 모델이 됩니다. $\to$ 그래서 예측할 때 잘 안씁니다.

# %% [markdown]
# `(2)` 0시점을 시작점으로 고정하고 $+\infty$로 보내는 방법

# %% [markdown]
# $Z_t$를 시작, $Z_{-\infty}$를 끝이라고 생각해서 푼것이 위에 식이라면, 시작과 끝을 바꿔서 생각하면 $y_0 = Z_{-\infty}=0$^[편의상 $Z_{-\infty}=0$으로 생각]

# %% [markdown]
# - $y_0 = 0$
# - $y_1 = y_0 + \epsilon_1$
# - $y_2 = y_1 + \epsilon_1 + \epsilon_2$
# - $y_3 = y_0 + \epsilon_1 + \epsilon_2 + \epsilon_3$
# - $\dots$
# - $y_t = y_0 + \epsilon_1 + \dots + \epsilon_t = \sum_{i=1}^t \epsilon_i \Rightarrow V(y_t) = t\sigma^2$

# %% [markdown]
# $t\to \infty$ 이므로, 결국 $t\sigma^2\to \infty$

# %% [markdown]
# 이것이 교재의 논리이고, 결국 위에서의 논리와 일치한다. (시작과 끝을 어디로 놓던지 상관없다. 단지 아래와 같이 생각한다면 $t$시점을 무한대로 보내줘야 한다는 차이가 존재함.)

# %% [markdown]
# # 5.2.5 auto-regressive process (AR)

# %% [markdown]
# $\{Z_t\}$ is auto regressive process iff.

# %% [markdown]
# $Z_t = \phi_1 Z_{t-1} + \phi_2 Z_{t-2} + \phi_3 Z_{t-3} + \dots + \phi_p Z_{t-p} + \epsilon_t$

# %% [markdown]
# ## motive1 : 과거의 값에 계수값 반영

# %% [markdown]
# 랜덤워크 방식이 너무 아까움.. 분산이 안터지는 방법이 없을까?

# %% [markdown]
# $Z_t = 0.999Z_{t-1} + \epsilon_t, \quad \epsilon_t \sim (0,\sigma^2)$
#
# - 현재=과거+오차

# %% [markdown]
# $\begin{align*}Z_t &= \epsilon_t + 0.999 Z_{t-1}\\
# &=\epsilon_t + 0.999(0.999Z_{t-2} + \epsilon_{t-1}) \\
# &=\epsilon_t + 0.999\epsilon_{t-1} + 0.999^2Z_{t-2}\\
# &\vdots \\
# &=\epsilon_t + 0.999\epsilon_{t-1} + 0.999^2 \epsilon_{t-2} + \dots \end{align*}$

# %% [markdown]
# $\begin{align*}V(Z_t) &= \sigma^2 + 0.999^2\sigma^2 + 0.999^4\sigma^2 + \dots\\
# &= \sigma^2(1+0.999^2+0.999^4+\dots) \quad \text{<- 무한등비급수}\\
# &= \sigma^2\frac{1}{1-0.999^2} < \infty \Rightarrow \text{t에 depend하지 X}
# \end{align*}$

# %% [markdown]
# - Covariance 구하는 것은 생략.. 결과는 $t$에 depend하지 않습니다.

# %% [markdown]
# 따라서 Stationary 하다!

# %% [markdown]
# ## motive2 : 기울기 텀 추가

# %% [markdown]
# 좀 더 좋은 모델을 만들고 싶은 욕심이 생긴다..

# %% [markdown]
# 이런 모델을 생각해본다.

# %% [markdown]
# ![motive2: 현재 = 과거 + 오차 + 기울기](attachment:b203c855-a95b-4748-b1c5-7ff5ea15b4dc.png)

# %% [markdown]
# 모델 : 현재 = 과거 + 오차 + 기세(기울기)^[기세를 넣어보고 싶다. 기세를 좀 더 수학적으로 표현하면 기울기]

# %% [markdown]
# $Z_t = \frac{0.9}{2}Z_{t-1} + \frac{(Z_{t-1} -Z_{t-2})}{2} + \epsilon_t$

# %% [markdown]
# $\quad\space = 0.45Z_{t-1} + \frac{1}{2}Z_{t-1} -\frac{1}{2}Z_{t-2} + \epsilon_t$

# %% [markdown]
# $\quad\space = 0.95Z_{t-1} - 0.5Z_{t-2} + \epsilon_t$

# %% [markdown]
# $\quad\space =\phi_1 Z_{t-1} + \phi_2Z_{t-2} + \phi_3Z_{t-3} + \dots + \phi_pZ_{t-p} + \epsilon_t$

# %% [markdown]
# 위의 두 모티브에 따라 Stationary를 만들기 위해 계수를 고려하고, 기울기를 적당히 추가해 고려하면 좀 더 일반적이고 설명이 잘 되는 모델을 만들 수 있을 것 같다.

# %% [markdown]
# 근데 결국 Stationary가 안되면 쓸모가 없으니까 모티브2의 모델이 Stationary를 만족하는지 확인해 볼 필요가 있다.

# %% [markdown]
# ## AR모델의 정상성 확인

# %% [markdown]
# `-` AR Process

# %% [markdown]
# $\{Z_t\}$ is AR process iff.

# %% [markdown]
# $Z_t = \phi_1Z_{t-1} + \phi_2Z_{t-2} + \dots + \phi_pZ_{t-p} + \epsilon_t$

# %% [markdown]
# $BZ_t = Z_{t-1}$를 만족하는 $B$^[back operator라고 합니다. $B$는 사실 변수는 아니라 operator인데 여기서는 변수처럼 취급할 것 입니다.]를 생각하자.

# %% [markdown]
# $BZ_{t-1} = Z_{t-2}$

# %% [markdown]
# $BBZ_{t} = Z_{t-2}$

# %% [markdown]
# $B^2Z_t = Z_{t-2}$

# %% [markdown]
# $\therefore Z_t = \phi_1BZ_t + \phi_2B^2Z_t + \dots \phi_pB^pZ_t + \epsilon_t$

# %% [markdown]
# $Z_t - \phi_1BZ_t - \phi_2B^2Z_t - \dots - \phi_pB^pZ_t = \epsilon_t$

# %% [markdown]
# $(1-\phi_1B-\phi_2B^2-\dots-\phi_pB^p)Z_t = \epsilon_t$

# %% [markdown]
# 여기에서 $(1-\phi_1B-\phi_2B^2-\dots-\phi_pB^p)=0$으로 놓은 식을 **특성방정식** 이라고 합니다.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>AR process의 정상성을 체크하는 법 (교재 p215, p246):</b><br><br>
#     1. 특성방정식을 구한다.<br>
#     2. 특성방정식을 $B$에 대하여 푼다.<br>
#     3. 모든 근의 절댓값이 1보다 큰지 조사한다.
# </div>

# %% [markdown]
# ### 연습문제 5.1 (h)

# %% [markdown]
# 다음 모형에 의해 설명되는 확률과정 $\{Z_t\}$는 정상성을 갖는지 조사하라.

# %% [markdown]
# $Z_t=100+0.5Z_{t-1}+\epsilon_t, \quad \{\epsilon_t\}$는 $WN(0,5)$ 이다.

# %% [markdown]
# ***`(sol)`***

# %% [markdown]
# $Z_t = 100 + 0.5Z_{t-1} + \epsilon_t.$^[절편이 있는 AR모델]

# %% [markdown]
# $\Leftrightarrow Z_t-200 = 0.5(Z_{t-1}-200) + \epsilon_t.$

# %% [markdown]
# 여기서 $Z_t - 200 = Y_t$로 놓고, $Z_{t-1}-200=Y_{t-1}$로 놓으면,

# %% [markdown]
# $Y_t = 0.5Y_{t-1} + \epsilon_t.$^[절편이 없는 AR모델]

# %% [markdown]
# $\{Z_t\}$의 정상성을 파악하는 일은 $\{Y_t\}$의 정상성을 파악하기만 하면 충분함.

# %% [markdown]
# ***`(참고)`*** 절편은 생략해도 됩니다. 절편이 있든 없든 AR모델의 정상성을 체크하고 AR모델의 성질을  파악하는 것은 차이가 없어요.

# %% [markdown]
# $Y_t = 0.5Y_{t-1} + \epsilon_t.$에서 $\{Y_t\}$가 정상인지만 판단하면 됩니다.

# %% [markdown]
# $\Leftrightarrow Y_t = 0.5BY_t +\epsilon_t$

# %% [markdown]
# $\Leftrightarrow Y_t-0.5BY_t = \epsilon_t$

# %% [markdown]
# $\Leftrightarrow (1-0.5B)Y_t = \epsilon_t$

# %% [markdown]
# $\therefore$ 특성방정식: $1-0.5B=0 \Rightarrow B=2 \Rightarrow |B|>1 \Rightarrow \{Y_t\}$는 정상.

# %% [markdown]
# $\Rightarrow \{Z_t\}$도 정상

# %% [markdown]
# ***`(다른 풀이)`*** -- 결과는 특성방정식을 이용해 푼 결과와 동일.

# %% [markdown]
# **<font color='blue'>관점1 (t: 시작, $-\infty$: 끝)</font>**

# %% [markdown]
# $E(Z_t) = E(Y_t+200) = 200$

# %% [markdown]
# $Y_t = 0.5Y_{t-1} +\epsilon_t$

# %% [markdown]
# $\quad = \epsilon_t + 0.5\epsilon_{t-1} + 0.5^2\epsilon_{t-2} + \dots + Y_{-\infty}.$^[$Y_{-\infty}=0$, 관점 $\Rightarrow t$ :시작, $-\infty$:끝]

# %% [markdown]
# $E(Y_t) = 0 + 0 + \dots + 0 = 0$

# %% [markdown]
# **<font color='blue'>관점2 (0: 시작, $\infty$: 끝)</font>**

# %% [markdown]
# $Z_t = 100 + 0.5Z_{t-1}+\epsilon_t$
#
# - $Z_0 = 0$
# - $Z_1 = 100 + 1\cdot\frac{1}{2}+\epsilon_1$
# - $Z_2 = 100 + (100+\epsilon_1)\frac{1}{2}+\epsilon_2$
# - $Z_3 = 100 + (100+(100+\epsilon_1)\frac{1}{2} + \epsilon_2) + \epsilon_3$
# - $Z_t = 100 + 100\times\frac{1}{2}+ 100\times \frac{1}{4} + \dots$

# %% [markdown]
# $\therefore E(Z_t) = \frac{100}{1-\frac{1}{2}}=200$ $\quad \leftarrow \text{not depend on t}$

# %% [markdown]
# 관점1과 2의 결과는 동일하다.

# %% [markdown]
# $Y_t = \epsilon_t + 0.5\epsilon_{t-1} + 0.5^2\epsilon_{t-2} + \cdots$

# %% [markdown]
# $V(Y_t) = 1 + 0.5^2 + 0.5^4 + \dots = \frac{1}{1-0.5^2}=\frac{4}{3}$ $\quad \leftarrow \text{not depend on t}$

# %% [markdown]
# ***lag=1:*** $\quad Cov(Y_t, Y_{t-1})$

# %% [markdown]
# $Cov(Y_t, Y_{t-1}) = Cov( \epsilon_t + 0.5\epsilon_{t-1} + 0.5^2\epsilon_{t-2} + \cdots,  0 +\epsilon_{t-1} + 0.5\epsilon_{t-2} + 0.5^2\epsilon_{t-3} + \cdots)$

# %% [markdown]
# $\begin{align*}\therefore Cov(Y_t, Y_{t-1}) &= 0+ 0.5\sigma^2 + 0.5^3\sigma^2 + 0.5^5\sigma^2 + \cdots \\
# &= \left(\frac{0.5}{1-0.5^2}\right)\sigma^2\end{align*}$  $\quad \leftarrow \text{not depend on t}$

# %% [markdown]
# ***lag=2:*** $\quad Cov(Y_t, Y_{t-2})$

# %% [markdown]
# $Cov(Y_t, Y_{t-2}) = Cov( \epsilon_t + 0.5\epsilon_{t-1} + 0.5^2\epsilon_{t-2} + \cdots,  0 + 0 +\epsilon_{t-2} + 0.5\epsilon_{t-3} + 0.5^2\epsilon_{t-4} + \cdots)$

# %% [markdown]
# $\begin{align*}\therefore Cov(Y_t, Y_{t-2}) &= 0+ 0+ 0.5^2\sigma^2 + 0.5^4\sigma^2 + 0.5^6\sigma^2 + \cdots \\
# &= \left(\frac{0.5^2}{1-0.5^2}\right)\sigma^2\end{align*}$  $\quad \leftarrow \text{not depend on t}$

# %% [markdown]
# ***lag=k:*** $\quad Cov(Y_t, Y_{t-k})$

# %% [markdown]
# $Cov(Y_t, Y_{t-k}) = \sigma^2\cdot\frac{0.5^k}{1-0.5^2} \quad \leftarrow \text{not depend on t}$

# %% [markdown]
# $\Rightarrow \{Y_t\} \text{ is stationary!}$

# %% [markdown]
# 특성방정식을 이용해 푼 결과와 동일하다. 특성방정식 매우 좋은 방법이였음..

# %% [markdown]
# ### 연습문제 5.1 (i)

# %% [markdown]
# $Z_t = 1.3Z_{t-1}+\epsilon_t, \quad  \epsilon_t \overset{iid}{\sim}(0,1)$

# %% [markdown]
# `(sol1)`

# %% [markdown]
# 특성방정식: $1-1.3B = 0 \Rightarrow B = \frac{1}{1.3}$

# %% [markdown]
# $\Rightarrow$ **"비정상시계열"**

# %% [markdown]
# `(sol2)`

# %% [markdown]
# $Z_t = \epsilon_t + 1.3\epsilon_{t-1} + 1.3^2\epsilon_{t-2}+\dots$

# %% [markdown]
# $V(Z_t)=\infty \Rightarrow $ **"비정상시계열"**

# %% [markdown]
# ## AR(1): 특성방정식보다 쉽게 정상성 판단하는 법
#
# > 단, AR(1) 모델 한정해서 정상성 체크. (p191, p218)

# %% [markdown]
# $\begin{align*}AR(1): Z_t &= \phi Z_{t-1} + \epsilon_t\\
# \Rightarrow Z_t &= \phi BZ_t + \epsilon\end{align*}$

# %% [markdown]
# $\therefore$ 특성방정식$=1-\phi B = 0 \to B=\frac{1}{\phi}$

# %% [markdown]
# 따라서 $|\frac{1}{\phi}| > 1$인지만 체크하면 됨. $\Leftrightarrow |\phi| < 1$

# %% [markdown]
# - 교재: 절편 무시/ 분산 & Cov 유한

# %% [markdown]
# **결국 AR(1): 현재 = $\phi$과거 + 오차**^[$\phi$는 계수를 의미. $0.3, 1.2, 1.8,...$ 등등] 에서
#
# - $|\phi| < 1 \Rightarrow$ 과거의 효과가 점차 사라진다.
# - 랜덤워크와의 차이점은 계수를 적당히 조절해서 수렴시키게 만들 수 있다는 것. 즉, 정상성을 만족하도록 만들 수 있다는 특징이 있다.

# %% [markdown]
# ## AR(2)과정이 정상일 조건

# %% [markdown]
# $Z_t = \phi_1 Z_{t-1} + \phi_2Z_{t-2} + \epsilon_t$

# %% [markdown]
# $Z_t = \phi+1BZ_t + \phi_2B^2Z_t + \epsilon_t$

# %% [markdown]
# 특성방정식: $1-\phi_2B - \phi_2B^2 = 0$

# %% [markdown]
# 근^[이차방정식 근의 공식 이용] : $\frac{\phi_1\pm \sqrt{\phi_1^2+4\phi_2}}{-2\phi_2}\quad$ 근의 절댓값이 1보다 클 조건.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>AR(2) 모델한정 정상성 쉽게 판단하는 법:</b><br><br>
#     1. $\phi_1 + \phi_2 < 1$<br>
#     2. $\phi_2 - \phi_1 < 1$<br>
#     3. $|\phi_2| < 1$ <br><br>
#
# 다음 조건과 같은 조건을 만족하는 AR(2) 과정을 정상이라고 하며, 특성방정식의 근의 절대값이 1보다 커야한다는 조건과 동치이다.
# </div>

# %% [markdown]
# ### 연습문제 5.1 (h)

# %% [markdown]
# $Z_t = 100 + 0.5Z_{t-1} + \epsilon_t$

# %% [markdown]
# 절편무시, $0.5 < 1 \Rightarrow$ "정상"

# %% [markdown]
# ### 연습문제 5.1 (i)

# %% [markdown]
# $Z_t = 1.3Z_{t-t} + \epsilon_t$

# %% [markdown]
# $1.3 > 1 \Rightarrow$ "비정상"

# %% [markdown]
# ### 연습문제 5.1 (l)

# %% [markdown]
# $Z_t = 0.12 + Z_{t-1} + \epsilon_t$

# %% [markdown]
# 절편무시 $\phi=1 \Rightarrow$ "비정상"

# %% [markdown]
# ---

# %% [markdown]
# ![자기공분산함수와 자기상관함수](attachment:31e80ce5-7025-4628-b9a5-017835e65b52.png)

# %% [markdown]
# ## `#` AR(1) acf를 구하자. (교재 6.1.1)

# %% [markdown]
# Leg $\{Z_t\}$ be $AR(1)$ with $\phi$. i.e

# %% [markdown]
# $\begin{align*}Z_t &= \phi Z_{t-1} +\epsilon_t, \quad \epsilon_t\sim (0,\sigma^2) \\ &=\epsilon_t + \phi \epsilon_{t-1} + \phi^2\epsilon_{t-2}+\dots\end{align*}$

# %% [markdown]
# ![$Cov(Z_t, Z_{t-h})](attachment:b35beeb1-0fa2-45b8-9fd2-5aa46cbf874c.png)

# %% [markdown]
# $\therefore Cov(Z_t, Z_{t-h}) = \frac{\phi^h}{1-\phi^2}\sigma^2=\gamma(h)$

# %% [markdown]
# $acf(h)=\frac{\gamma(h)}{\gamma(0)}=\frac{\frac{\phi^h}{1-\phi^2}}{\frac{1}{1-\phi^2}}=\phi^h$^[교재 5.3 참고]

# %% [markdown]
# ![acf를 쉽게 계산하는 방법 따윈 없어.. 정석대로 하자.](attachment:692f7dd5-78df-47b7-a388-34565ae03446.png)

# %% [markdown]
# ## $\gamma(h)$와 $\text{acf}(h)$의 성질 (교재 5.3)

# %% [markdown]
# ![성질1. 분산은 시간에 depend 하지 않으니까~](attachment:508f387f-1d6d-477a-b2c1-f05d24e75e1b.png)

# %% [markdown]
# ![성질2.](attachment:b75d3a32-a377-48ab-b967-c9120408127d.png)

# %% [markdown]
# ![성질3.](attachment:7a40d83b-5efa-4b0f-930c-74c8250b3700.png)

# %% [markdown]
# ![성질4. 코쉬-슈바르츠로 증명 가능](attachment:ebce9b23-e076-4cb2-ade0-2e281a28f371.png)

# %% [markdown]
# ## `#` $AR(2)$ $\text{ACF}$를 구하라.

# %% [markdown]
# ![](attachment:b6778386-78d4-4e15-b814-1d2489f1a965.png)

# %% [markdown]
# ![](attachment:1194c5f4-4efd-4005-b7aa-beb58908c159.png)

# %% [markdown]
# ![](attachment:5d40c635-be25-4412-b1a8-cb22f98bd8b5.png)

# %% [markdown]
# ![](attachment:6e745863-41df-4121-a008-cb0d70a26e53.png)

# %% [markdown]
# ![](attachment:7922ffcb-86f3-4140-999b-423e9d9abdb9.png)

# %% [markdown]
# ![](attachment:d094840e-bbdd-4869-886b-5cd09bd901b4.png)

# %% [markdown]
# ![](attachment:62febda0-72eb-457d-a5d4-cf7b4a867df4.png)

# %% [markdown]
# ![](attachment:3b678058-0a20-4646-8ae2-b0edc0f1c42c.png)

# %% [markdown]
# ## 교재6.1.2 AR(2)의 ACF 형태.

# %% [markdown]
# ![AR(2)의 ACF 형태](attachment:91d5b58f-56bf-4d41-a1c6-bbfb43d38668.png)

# %% [markdown]
# ![Type1. 지수적으로 감소, Type2. 점차 소멸하는 sin 함수](attachment:2e9d3afb-9406-46a1-8874-72d04f45d740.png)

# %% [markdown]
# ![](attachment:e48734bf-b51e-4985-bf84-ce7584990861.png)
