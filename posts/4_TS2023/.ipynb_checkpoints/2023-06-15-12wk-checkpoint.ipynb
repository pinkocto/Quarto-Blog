# %% [raw]
# ---
# title: " **[TS]** 12wk. 추세 (++)"
# author: "jiyunLim"
# date: "05/24/2023"
# categories:
#     - STUDY
#     - TS
# ---

# %% [markdown]
# ![](attachment:f148679b-91fa-45ee-abfb-df6775b6e88c.png)

# %% [markdown]
# ![](attachment:e2fb1460-55cb-4d42-833d-986f5ae529c3.png)

# %% [markdown]
# ![](attachment:f2281e64-788e-45ee-b2c3-51cd911f20b7.png)
