# %% [raw]
# ---
# title: "Pandas 2단계"
# author: "jiyun Lim"
# date: "03/14/2023"
# categories:
#   - Python
#   - Pandas
# ---

# %% [markdown]
# # [(10주차) 5월6일](https://guebin.github.io/IP2022/2022/05/04/(10%EC%A3%BC%EC%B0%A8)-5%EC%9B%946%EC%9D%BC.html)

# %% [markdown]
# > 하나 혹은 여러개의 col$\cdot$row 선택하는 법

# %% [markdown]
# ## pandas 공부 2단계

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# `-` 데이터

# %%
np.random.seed(43052)
att = np.random.choice(np.arange(10,21)*5,20)
rep = np.random.choice(np.arange(5,21)*5,20)
mid = np.random.choice(np.arange(0,21)*5,20)
fin = np.random.choice(np.arange(0,21)*5,20)
key = ['202212'+str(s) for s in np.random.choice(np.arange(300,501),20,replace=False)]

# %%
df=pd.DataFrame({'att':att,'rep':rep,'mid':mid,'fin':fin},index=key)
df
# Out:
#            att  rep  mid  fin
# 202212380   65   55   50   40
# 202212370   95  100   50   80
# 202212363   65   90   60   30
# 202212488   55   80   75   80
# 202212312   80   30   30  100
# 202212377   75   40  100   15
# 202212463   65   45   45   90
# 202212471   60   60   25    0
# 202212400   95   65   20   10
# 202212469   90   80   80   20
# 202212318   55   75   35   25
# 202212432   95   95   45    0
# 202212443   95   55   15   35
# 202212367   50   80   40   30
# 202212458   50   55   15   85
# 202212396   95   30   30   95
# 202212482   50   50   45   10
# 202212452   65   55   15   45
# 202212387   70   70   40   35
# 202212354   90   90   80   90

# %% [markdown]
# ### 첫번쨰 칼럼을 선택

# %% [markdown]
# `-` 방법1

# %%
df.att
# Out:
# 202212380    65
# 202212370    95
# 202212363    65
# 202212488    55
# 202212312    80
# 202212377    75
# 202212463    65
# 202212471    60
# 202212400    95
# 202212469    90
# 202212318    55
# 202212432    95
# 202212443    95
# 202212367    50
# 202212458    50
# 202212396    95
# 202212482    50
# 202212452    65
# 202212387    70
# 202212354    90
# Name: att, dtype: int64

# %% [markdown]
# `-` 방법2: dict 스타일

# %%
df['att']
# Out:
# 202212380    65
# 202212370    95
# 202212363    65
# 202212488    55
# 202212312    80
# 202212377    75
# 202212463    65
# 202212471    60
# 202212400    95
# 202212469    90
# 202212318    55
# 202212432    95
# 202212443    95
# 202212367    50
# 202212458    50
# 202212396    95
# 202212482    50
# 202212452    65
# 202212387    70
# 202212354    90
# Name: att, dtype: int64

# %%
type(df['att'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# `-` 방법3: dict 스타일

# %%
df[['att']]
# Out:
#            att
# 202212380   65
# 202212370   95
# 202212363   65
# 202212488   55
# 202212312   80
# 202212377   75
# 202212463   65
# 202212471   60
# 202212400   95
# 202212469   90
# 202212318   55
# 202212432   95
# 202212443   95
# 202212367   50
# 202212458   50
# 202212396   95
# 202212482   50
# 202212452   65
# 202212387   70
# 202212354   90

# %%
type(df[['att']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# - df.att나 `df['att']`는 series를 리턴하고 `df[['att']]`는 dataframe을 리턴한다.

# %% [markdown]
# `-` 방법4: ndarray스타일

# %%
df.iloc[:,0]
# Out:
# 202212380    65
# 202212370    95
# 202212363    65
# 202212488    55
# 202212312    80
# 202212377    75
# 202212463    65
# 202212471    60
# 202212400    95
# 202212469    90
# 202212318    55
# 202212432    95
# 202212443    95
# 202212367    50
# 202212458    50
# 202212396    95
# 202212482    50
# 202212452    65
# 202212387    70
# 202212354    90
# Name: att, dtype: int64

# %%
type(df.iloc[:,0] )
# Out:
# pandas.core.series.Series

# %% [markdown]
# `-` 방법5: ndarray 스타일

# %%
df.iloc[:,[0]]
# Out:
#            att
# 202212380   65
# 202212370   95
# 202212363   65
# 202212488   55
# 202212312   80
# 202212377   75
# 202212463   65
# 202212471   60
# 202212400   95
# 202212469   90
# 202212318   55
# 202212432   95
# 202212443   95
# 202212367   50
# 202212458   50
# 202212396   95
# 202212482   50
# 202212452   65
# 202212387   70
# 202212354   90

# %%
type(df.iloc[:,[0]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# - df.iloc[:,0]은 series를 리턴하고 df.iloc[:,[0]]은 dataframe을 리턴한다.

# %% [markdown]
# `-` 방법6: ndarray 스타일과 dict스타일의 혼합

# %%
df.loc[:,'att']
# Out:
# 202212380    65
# 202212370    95
# 202212363    65
# 202212488    55
# 202212312    80
# 202212377    75
# 202212463    65
# 202212471    60
# 202212400    95
# 202212469    90
# 202212318    55
# 202212432    95
# 202212443    95
# 202212367    50
# 202212458    50
# 202212396    95
# 202212482    50
# 202212452    65
# 202212387    70
# 202212354    90
# Name: att, dtype: int64

# %% [markdown]
# `-` 방법7: ndarray 스타일과 dict스타일의 혼합

# %%
df.loc[:,['att']]
# Out:
#            att
# 202212380   65
# 202212370   95
# 202212363   65
# 202212488   55
# 202212312   80
# 202212377   75
# 202212463   65
# 202212471   60
# 202212400   95
# 202212469   90
# 202212318   55
# 202212432   95
# 202212443   95
# 202212367   50
# 202212458   50
# 202212396   95
# 202212482   50
# 202212452   65
# 202212387   70
# 202212354   90

# %% [markdown]
# - `df.loc[:,'att']`은 series를 리턴하고 `df.loc[:,['att']]` 은 dataframe을 리턴한다.

# %% [markdown]
# `-` 방법7: ndarray 스타일 + bool 인덱싱

# %%
df.iloc[:,[True,False,False,False]]
# Out:
#            att
# 202212380   65
# 202212370   95
# 202212363   65
# 202212488   55
# 202212312   80
# 202212377   75
# 202212463   65
# 202212471   60
# 202212400   95
# 202212469   90
# 202212318   55
# 202212432   95
# 202212443   95
# 202212367   50
# 202212458   50
# 202212396   95
# 202212482   50
# 202212452   65
# 202212387   70
# 202212354   90

# %% [markdown]
# `-` 방법8: ndarray와 dict의 혼합형 + bool 인덱싱

# %%
df.loc[:,[True,False,False,False]]
# Out:
#            att
# 202212380   65
# 202212370   95
# 202212363   65
# 202212488   55
# 202212312   80
# 202212377   75
# 202212463   65
# 202212471   60
# 202212400   95
# 202212469   90
# 202212318   55
# 202212432   95
# 202212443   95
# 202212367   50
# 202212458   50
# 202212396   95
# 202212482   50
# 202212452   65
# 202212387   70
# 202212354   90

# %% [markdown]
# ### 여러개의 칼럼을 선택

# %% [markdown]
# `-` 방법1: dict 스타일

# %%
df[['att','fin']]
# Out:
#            att  fin
# 202212380   65   40
# 202212370   95   80
# 202212363   65   30
# 202212488   55   80
# 202212312   80  100
# 202212377   75   15
# 202212463   65   90
# 202212471   60    0
# 202212400   95   10
# 202212469   90   20
# 202212318   55   25
# 202212432   95    0
# 202212443   95   35
# 202212367   50   30
# 202212458   50   85
# 202212396   95   95
# 202212482   50   10
# 202212452   65   45
# 202212387   70   35
# 202212354   90   90

# %% [markdown]
# `-` 방법2: ndarray 스타일 (정수리스트로 인덱싱, 슬라이싱, 스트라이딩)

# %%
df.iloc[:,[0,1]] # 정수의 리스트를 전달하여 컬럼추출
# Out:
#            att  rep
# 202212380   65   55
# 202212370   95  100
# 202212363   65   90
# 202212488   55   80
# 202212312   80   30
# 202212377   75   40
# 202212463   65   45
# 202212471   60   60
# 202212400   95   65
# 202212469   90   80
# 202212318   55   75
# 202212432   95   95
# 202212443   95   55
# 202212367   50   80
# 202212458   50   55
# 202212396   95   30
# 202212482   50   50
# 202212452   65   55
# 202212387   70   70
# 202212354   90   90

# %%
df.iloc[:,range(2)]
# Out:
#            att  rep
# 202212380   65   55
# 202212370   95  100
# 202212363   65   90
# 202212488   55   80
# 202212312   80   30
# 202212377   75   40
# 202212463   65   45
# 202212471   60   60
# 202212400   95   65
# 202212469   90   80
# 202212318   55   75
# 202212432   95   95
# 202212443   95   55
# 202212367   50   80
# 202212458   50   55
# 202212396   95   30
# 202212482   50   50
# 202212452   65   55
# 202212387   70   70
# 202212354   90   90

# %%
df.iloc[:,:2]  # 슬라이싱 , 0,1,2에서 마지막 2는 제외되고 0,1에 해당하는 것만 추출
# Out:
#            att  rep
# 202212380   65   55
# 202212370   95  100
# 202212363   65   90
# 202212488   55   80
# 202212312   80   30
# 202212377   75   40
# 202212463   65   45
# 202212471   60   60
# 202212400   95   65
# 202212469   90   80
# 202212318   55   75
# 202212432   95   95
# 202212443   95   55
# 202212367   50   80
# 202212458   50   55
# 202212396   95   30
# 202212482   50   50
# 202212452   65   55
# 202212387   70   70
# 202212354   90   90

# %%
df.iloc[:,::2]  # 스트라이딩
# Out:
#            att  mid
# 202212380   65   50
# 202212370   95   50
# 202212363   65   60
# 202212488   55   75
# 202212312   80   30
# 202212377   75  100
# 202212463   65   45
# 202212471   60   25
# 202212400   95   20
# 202212469   90   80
# 202212318   55   35
# 202212432   95   45
# 202212443   95   15
# 202212367   50   40
# 202212458   50   15
# 202212396   95   30
# 202212482   50   45
# 202212452   65   15
# 202212387   70   40
# 202212354   90   80

# %% [markdown]
# `-` 방법3: ndarray와 dict의 혼합형

# %%
df.loc[:,['att','mid']]
# Out:
#            att  mid
# 202212380   65   50
# 202212370   95   50
# 202212363   65   60
# 202212488   55   75
# 202212312   80   30
# 202212377   75  100
# 202212463   65   45
# 202212471   60   25
# 202212400   95   20
# 202212469   90   80
# 202212318   55   35
# 202212432   95   45
# 202212443   95   15
# 202212367   50   40
# 202212458   50   15
# 202212396   95   30
# 202212482   50   45
# 202212452   65   15
# 202212387   70   40
# 202212354   90   80

# %%
df.loc[:,'att':'mid']  # 마지막의 mid도 포함된다.
# Out:
#            att  rep  mid
# 202212380   65   55   50
# 202212370   95  100   50
# 202212363   65   90   60
# 202212488   55   80   75
# 202212312   80   30   30
# 202212377   75   40  100
# 202212463   65   45   45
# 202212471   60   60   25
# 202212400   95   65   20
# 202212469   90   80   80
# 202212318   55   75   35
# 202212432   95   95   45
# 202212443   95   55   15
# 202212367   50   80   40
# 202212458   50   55   15
# 202212396   95   30   30
# 202212482   50   50   45
# 202212452   65   55   15
# 202212387   70   70   40
# 202212354   90   90   80

# %%
df.loc[:,'rep':]
# Out:
#            rep  mid  fin
# 202212380   55   50   40
# 202212370  100   50   80
# 202212363   90   60   30
# 202212488   80   75   80
# 202212312   30   30  100
# 202212377   40  100   15
# 202212463   45   45   90
# 202212471   60   25    0
# 202212400   65   20   10
# 202212469   80   80   20
# 202212318   75   35   25
# 202212432   95   45    0
# 202212443   55   15   35
# 202212367   80   40   30
# 202212458   55   15   85
# 202212396   30   30   95
# 202212482   50   45   10
# 202212452   55   15   45
# 202212387   70   40   35
# 202212354   90   80   90

# %% [markdown]
# `-` 방법4: bool을 이용한 인덱싱

# %%
df.iloc[:,[True,False,True,False]]
# Out:
#            att  mid
# 202212380   65   50
# 202212370   95   50
# 202212363   65   60
# 202212488   55   75
# 202212312   80   30
# 202212377   75  100
# 202212463   65   45
# 202212471   60   25
# 202212400   95   20
# 202212469   90   80
# 202212318   55   35
# 202212432   95   45
# 202212443   95   15
# 202212367   50   40
# 202212458   50   15
# 202212396   95   30
# 202212482   50   45
# 202212452   65   15
# 202212387   70   40
# 202212354   90   80

# %%
df.loc[:,[True,False,True,False]]
# Out:
#            att  mid
# 202212380   65   50
# 202212370   95   50
# 202212363   65   60
# 202212488   55   75
# 202212312   80   30
# 202212377   75  100
# 202212463   65   45
# 202212471   60   25
# 202212400   95   20
# 202212469   90   80
# 202212318   55   35
# 202212432   95   45
# 202212443   95   15
# 202212367   50   40
# 202212458   50   15
# 202212396   95   30
# 202212482   50   45
# 202212452   65   15
# 202212387   70   40
# 202212354   90   80

# %% [markdown]
# ### 첫번째 행을 선택

# %% [markdown]
# `-` 방법1

# %%
df.iloc[0]
# Out:
# att    65
# rep    55
# mid    50
# fin    40
# Name: 202212380, dtype: int64

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %% [markdown]
# `-` 방법2

# %%
df.iloc[[0]]
# Out:
#            att  rep  mid  fin
# 202212380   65   55   50   40

# %%
type(df.iloc[[0]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# `-` 방법3

# %%
df.iloc[0,:]
# Out:
# att    65
# rep    55
# mid    50
# fin    40
# Name: 202212380, dtype: int64

# %%
type(df.iloc[0,:])
# Out:
# pandas.core.series.Series

# %% [markdown]
# `-` 방법4

# %%
df.iloc[[0],:]
# Out:
#            att  rep  mid  fin
# 202212380   65   55   50   40

# %%
type(df.iloc[[0],:])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# `-` 방법5

# %%
df.loc['202212380']
# Out:
# att    65
# rep    55
# mid    50
# fin    40
# Name: 202212380, dtype: int64

# %%
type(df.loc['202212380'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# `-` 방법6

# %%
df.loc[['202212380']]
# Out:
#            att  rep  mid  fin
# 202212380   65   55   50   40

# %%
type(df.loc[['202212380']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# `-` 방법7

# %%
df.loc['202212380',:]
# Out:
# att    65
# rep    55
# mid    50
# fin    40
# Name: 202212380, dtype: int64

# %%
type(df.loc['202212380',:])
# Out:
# pandas.core.series.Series

# %% [markdown]
# `-` 방법8

# %%
df.loc[['202212380'],:]
# Out:
#            att  rep  mid  fin
# 202212380   65   55   50   40

# %%
type(df.loc[['202212380'],:])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# `-` 방법9

# %%
len(df)
# Out:
# 20

# %%
_lst = [True]+[False]*19

# %%
df.iloc[_lst]
# Out:
#            att  rep  mid  fin
# 202212380   65   55   50   40

# %%
df.iloc[_lst,:]
# Out:
#            att  rep  mid  fin
# 202212380   65   55   50   40

# %%
df.loc[_lst]
# Out:
#            att  rep  mid  fin
# 202212380   65   55   50   40

# %%
df.loc[_lst,:]
# Out:
#            att  rep  mid  fin
# 202212380   65   55   50   40

# %% [markdown]
# ### 여러개의 행을 선택

# %% [markdown]
# `-` 방법1

# %%
df.iloc[[0,2]]
# Out:
#            att  rep  mid  fin
# 202212380   65   55   50   40
# 202212363   65   90   60   30

# %%
df.iloc[[0,2],:]
# Out:
#            att  rep  mid  fin
# 202212380   65   55   50   40
# 202212363   65   90   60   30

# %% [markdown]
# `-` 방법2

# %%
df.loc[['202212380','202212363']]
# Out:
#            att  rep  mid  fin
# 202212380   65   55   50   40
# 202212363   65   90   60   30

# %%
df.loc[['202212380','202212363'],:]
# Out:
#            att  rep  mid  fin
# 202212380   65   55   50   40
# 202212363   65   90   60   30

# %% [markdown]
# `-` 그 밖의 방법들

# %%
df.iloc[::3] # 스트라이딩
# Out:
#            att  rep  mid  fin
# 202212380   65   55   50   40
# 202212488   55   80   75   80
# 202212463   65   45   45   90
# 202212469   90   80   80   20
# 202212443   95   55   15   35
# 202212396   95   30   30   95
# 202212387   70   70   40   35

# %%
df.iloc[:5]
# Out:
#            att  rep  mid  fin
# 202212380   65   55   50   40
# 202212370   95  100   50   80
# 202212363   65   90   60   30
# 202212488   55   80   75   80
# 202212312   80   30   30  100

# %%
df.loc[:'202212312']
# Out:
#            att  rep  mid  fin
# 202212380   65   55   50   40
# 202212370   95  100   50   80
# 202212363   65   90   60   30
# 202212488   55   80   75   80
# 202212312   80   30   30  100

# %%
df.loc[list(df.att<80),'rep':]
# Out:
#            rep  mid  fin
# 202212380   55   50   40
# 202212363   90   60   30
# 202212488   80   75   80
# 202212377   40  100   15
# 202212463   45   45   90
# 202212471   60   25    0
# 202212318   75   35   25
# 202212367   80   40   30
# 202212458   55   15   85
# 202212482   50   45   10
# 202212452   55   15   45
# 202212387   70   40   35

# %%
df.loc[df.att<80,'rep':]
# Out:
#            rep  mid  fin
# 202212380   55   50   40
# 202212363   90   60   30
# 202212488   80   75   80
# 202212377   40  100   15
# 202212463   45   45   90
# 202212471   60   25    0
# 202212318   75   35   25
# 202212367   80   40   30
# 202212458   55   15   85
# 202212482   50   45   10
# 202212452   55   15   45
# 202212387   70   40   35

# %%
df.iloc[list(df.att<80),1:]
# Out:
#            rep  mid  fin
# 202212380   55   50   40
# 202212363   90   60   30
# 202212488   80   75   80
# 202212377   40  100   15
# 202212463   45   45   90
# 202212471   60   25    0
# 202212318   75   35   25
# 202212367   80   40   30
# 202212458   55   15   85
# 202212482   50   45   10
# 202212452   55   15   45
# 202212387   70   40   35

# %% [markdown]
# `-` 아래는 에러가 난다 주의!

# %%
df.iloc[df.att<80, 1:]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/indexing.py:873, in _LocationIndexer._validate_tuple_indexer(self, key)
#     872 try:
# --> 873     self._validate_key(k, i)
#     874 except ValueError as err:
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/indexing.py:1457, in _iLocIndexer._validate_key(self, key, axis)
#    1452         raise NotImplementedError(
#    1453             "iLocation based boolean "
#    1454             "indexing on an integer type "
#    1455             "is not available"
#    1456         )
# -> 1457     raise ValueError(
#    1458         "iLocation based boolean indexing cannot use "
#    1459         "an indexable as a mask"
#    1460     )
#    1461 return
#
# ValueError: iLocation based boolean indexing cannot use an indexable as a mask
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 df.iloc[df.att<80, 1:]
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# File ~/anaconda3/envs/py38/lib/python3.8/site-packages/pandas/core/indexing.py:875, in _LocationIndexer._validate_tuple_indexer(self, key)
#     873         self._validate_key(k, i)
#     874     except ValueError as err:
# --> 875         raise ValueError(
#     876             "Location based indexing can only have "
#     877             f"[{self._valid_types}] types"
#     878         ) from err
#     879 return key
#
# ValueError: Location based indexing can only have [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array] types
