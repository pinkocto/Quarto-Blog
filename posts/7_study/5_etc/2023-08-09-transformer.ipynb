# %% [raw]
# ---
# title: "Attention is all you need"
# author: "JiyunLim"
# date: "08/09/2023"
# ---

# %% [markdown]
# ref: <https://arxiv.org/abs/1706.03762>

# %% [markdown]
# ![](attachment:1e6281c3-be19-4009-84fa-3aa6fff6358f.png)
