# %% [raw]
# ---
# title: "[Python] Syllabus"
# author: "JiyunLim"
# date: "07/10/2023"
# ---

# %% [markdown]
# > 파이썬 특강 일자별 강의내용

# %% [markdown]
# link: <https://stat.jbnu.ac.kr/stat/6442/subview.do?enc=>

# %% [markdown]
# ![](attachment:d2725331-87b6-479d-9c9e-90f92663fae1.png)

# %% [markdown]
# - ref: <https://guebin.github.io/IP2023WIN/>
