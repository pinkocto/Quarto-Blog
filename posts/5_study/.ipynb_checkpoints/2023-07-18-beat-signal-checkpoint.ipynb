# %% [raw]
# ---
# title: "Beat signal"
# author: "jiyun Lim"
# date: "07/22/2023"
# categories:
#   - Study
# ---

# %% [markdown]
# 덧셈으로 되어있지만 곱셈으로도 볼 수 있다.

# %% [markdown]
# # Wave inference
#
# - ref: <https://en.wikipedia.org/wiki/Wave_interference>
# - ref: <https://ko.wikipedia.org/wiki/%EA%B0%84%EC%84%AD_(%ED%8C%8C%EB%8F%99_%EC%A0%84%ED%8C%8C)>

# %% [markdown]
# **간섭(wave inference)** 현상은 물리학에서 파동이 위상을 지니기 때문에 발생하는 진폭의 공간적인 보강과 상쇄현상을 말한다. 일반적으로 두 개 이상의 파가 동시에 한 점에 도달했을 때 그 점에서 이들의 파가 강하게 합쳐지거나 약하게 합쳐지는 현상을 파의 간섭이라 한다.

# %% [markdown]
# `-` 정의

# %% [markdown]
# 간섭이란 물리적으로 두 가지 이상의 파장이 첨가되어, 새로운 파장의 형태를 나타내는 것을 의미한다. 가장 널리 사용되는 간섭의 관점은 서로 소멸되거나 서로 보강되는 파장들의 상호 작용에 관한 것이고, 그 이유는 그 파장들이 같은 광원에서 오는 것이거나 완벽에 가깝거나 그와 같은 주파수를 가지고 있기 때문이다. 만약 두 개의 파장이 정확히 같지 않은 파장 영역을 가지고 있고, 각각의 만들어지는 파장에서 같은 수의 상 차이를 보인다면, 두 개의 비 단일파장들도 서로 완벽히 보강된다.
#
# 만약 파동들이 두 개 이상의 다른 원으로부터 발생된다면, 총 상의 차이는 두개의 파형의 차이와 초기 상차이의 합에 의해 야기된다. 이 같은 결론은 파장이 정확하게 파장의 시작점과 같은 점에서 끝이 나는가(in phase) 혹은 그렇지 않은가(out phase)에 따라 알 수 있다.

# %% [markdown]
# `-` 보강간섭

# %% [markdown]
# 같은 위상의 두 파동이 중첩될 때 일어나는 간섭이다. 마루와 마루 또는 골과 골이 만나서 합성파의 진폭이 2배로 커진다.

# %% [markdown]
# 같은 진폭과 진동수를 가진 두 파동이 어느 순간 같은 영역을 통과할 때 나타나는 순간의 결과로서, 두 파동의 위상이 같아 마루와 마루가 만나고, 골이 골을 만나도록 중첩되는 순간 생기는 파동은 원래의 파동과 진동수는 같고 진폭이 2배이다. 이럴 때 파동은 위상이 같은 보강간섭을 한다고 말한다.

# %% [markdown]
# `-` 상쇄간섭

# %% [markdown]
# 반대 위상의 두 파동이 중첩될 때의 간섭이다. 마루와 골이 만나서 합성파의 진폭이 $0$이 되는 간섭으로 소멸간섭이라고도 한다.

# %% [markdown]
# 같은 진폭과 진동수를 가진 두 파동이 어느 순간 같은 영역을 통과할 때 나타나는 순간의 결과로서, 두 파동의 위상이 $180^{\circ}$ 어긋나 있을 때 마루와 골이 중첩되는 순간 생기는 파동은 완전히 상쇄된다.

# %% [markdown]
# # Beat Signal

# %% [markdown]
# - ref(위키): <https://en.wikipedia.org/wiki/Beat_(acoustics)>
#
# - ref: <https://www.animations.physics.unsw.edu.au/jw/beats.htm>
#
# - [Beat Notes: An interesting Observation](https://www.dsprelated.com/showarticle/189.php)

# %% [markdown]
# ![위키](attachment:fbf31a05-af0a-4aa8-8948-4d29121f0f17.png)

# %% [markdown]
# 어쿠스틱에서 비트는 **약간 다른** 두 소리 사이의 간섭 패턴(interference pattern)으로, 두 주파수의 차이만큼 주기적인 진폭(음량)변화로 인식됩니다.

# %% [markdown]
# 지속적인 음색을 낼 수 있는 튜닝 악기를 사용하면 비트를 쉽게 인식할 수 있습니다. 두 톤을 하나의 톤으로 튜닝하면 고유한 효과를 얻을 수 있습니다. <font color='blue'>두 톤이 피치가 비슷하지만 동일하지 않을 때 주파수 차이로 인해 비트가 발생합니다.</font>

# %% [markdown]
# 소리가 구조적으로 그리고 파괴적으로 번갈아 가며 간섭하기 때문에 음량은 마치 트레몰로처럼 변합니다. 두 음이 점차 일치하면서 박자가 느려지고 감지할 수 없을 정도로 느려질 수 있습니다. 두 음조가 멀어질수록 그들의 박자 주파수는 인간의 음높이 지각 범위에 접근하기 시작하고, 박자는 음표처럼 들리기 시작하고, 조합된 음조가 생성됩니다.

# %% [markdown]
# # Mathematics and physics of beat tones

# %% [markdown]
# 이 현상은 음향이나 음악에서 가장 잘 알려져 있지만 모든 선형 시스템에서 찾을 수 있습니다 . 두 현 의 전체 소리에 해당하는 함수를 보여주기 위해 그래프를 그려보면 최대값과 최소값은 순수한 음을 연주할 때처럼 더 이상 일정하지 않고 시간이 지남에 따라 변한다는 것을 알 수 있습니다. 두 파동의 위상이 거의 180도 어긋나면 한 파동의 최대값이 다른 파동의 최소값을 상쇄하는 반면 거의 위상이 일치하면 최대값이 합쳐져 인지되는 볼륨이 높아 집니다 .
#
# 최대값과 최소값의 엔벨로프가 두 원래 파동의 주파수 차이의 절반인 주파수를 갖는 파동을 형성한다는 것은 합계 대 곱 삼각법 항등식( 삼각법 항등식 목록 참조 ) 의 도움으로 입증될 수 있습니다 .

# %% [markdown]
# $$\cos(2\pi f_1 t) + \cos (2\pi f_2 t)=2\cos\left(2\pi \frac{f_1+f_2}{2}t\right)\cos\left(2\pi \frac{f_1-f_2}{2}t\right)$$

# %% [markdown]
# # Example

# %% [markdown]
# **Beat Notes**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Fs = 8192 # Sample rate of dig. samples
N = 8192  # Number of time samples
n = np.arange(N)
 
wave_1 = np.sin(2*np.pi*210*n/Fs);  # First tone, 210 Hz
wave_2 = np.sin(2*np.pi*200*n/Fs);  # Second tone, 200 Hz
wave_prod = wave_1*wave_2 
wave_sum = wave_1+wave_2

# %%
end_point = 2000
fig, axes = plt.subplots(3,1)
axes[0].plot(wave_1[:end_point], label='wave1')
axes[0].plot(wave_2[:end_point], label='wave2')
axes[0].set_title('wave1 & wave2')
axes[1].plot(wave_prod[:end_point])
axes[1].set_title('wave1*wave2')
axes[2].plot(wave_sum[:end_point])
axes[2].set_title('wave1+wave2')
plt.tight_layout()

# %%
plt.figure(figsize=(10,5)) # (가로, 세로)
plt.plot(wave_1[:500])
plt.plot(wave_2[:500])
plt.plot(wave_1[:500] + wave_2[:500])
